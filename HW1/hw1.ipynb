# %% [markdown]
# # 作业1：问卷+环境配置

# %% [markdown]
# ## 0. 说明

# %% [markdown]
# ### 0.1 关于 Jupyter Notebook

# %% [markdown]
# Jupyter Notebook 是一种可编程的文档类型，类似于 R Markdown。Jupyter Notebook 文档以一个个单元格组成，每个单元格可以是 Markdown 或者 Python 代码：前者通常用来写文字说明，后者用来运行代码。比如你双击第一行的标题，就会看到标题的 Markdown 代码（以 `#` 符号开头），再按 `Ctrl+Enter`，就会显示 Markdown 渲染的结果。

# %% [markdown]
# 而对于代码单元格， `Ctrl+Enter` 会执行单元格内的代码，例如用鼠标点击下面的单元格然后按键后会出现形如 `Out[x]` 的输出结果。

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# 我们的作业中既有需要说明的文字，又有需要编写的程序，前者用 Markdown 单元格，后者用代码单元格。单元格的类型可以在上方的下拉菜单中选择，也可以通过快捷键实现（通过菜单 Cell => Cell Type 查看）。

# %% [markdown]
# ### 0.2 关于 Markdown

# %% [markdown]
# Markdown 是常用的文档格式化语法，如果有不熟悉的，可以参考[这里](https://www.jianshu.com/p/335db5716248)的教程。需要说明的是 Jupyter Notebook 里可以插入数学公式，例如 $f(x)=\frac{1}{\sqrt{2\pi}}e^{-x^2/2}$。双击这个单元格来查看源代码。

# %% [markdown]
# ## 1. 问卷

# %% [markdown]
# 思考并回答**至少四个**问题：

# %% [markdown]
# - 你的未来规划（近期或长期）是什么？

# %% [markdown]
# - 凭第一印象，你觉得分布式计算是做什么的？

# %% [markdown]
# 在仅仅知道“分布式计算”这个名词时，我从字面上将分布式计算理解成“分步式”计算，尽管具体的汉字并不同。所以顾名思义，我会觉得它应该是将一个较大的计算问题**划分**成几个部分，然后**一步步**（也就是“*一布布*”地）进行计算。至于为什么拆解，可能是因为这样能更快速高效地达成目标。

# %% [markdown]
# - 你期待从这门课中学到什么？

# %% [markdown]
# - 你还有哪些喜欢的获取知识的渠道（例如B站，知乎，技术博客，公众号等）？如果有请向大家推荐一些，**具体到账号或网址**，不需要与深度学习相关。

# %% [markdown]
# 1. B站up主
#    - [*欧拉的费米子*](https://space.bilibili.com/142321694)，非常多数学相关课程的经典视频，比如他高清修复的[*数学分析-陈纪修*](https://www.bilibili.com/video/BV15v411g7VP/?spm_id_from=333.999.0.0&vd_source=35c56db6be8b98ea48484eddbc63284b)
#    - [*多明海*](https://space.bilibili.com/584762039?spm_id_from=333.337.0.0)，现代史分析和解说，比如他小有名气的[*韩国系列*](https://www.bilibili.com/video/BV18L4y1z78q/?spm_id_from=333.999.0.0&vd_source=35c56db6be8b98ea48484eddbc63284b)
#    - [*熊浩bearhow*](https://space.bilibili.com/450946369?spm_id_from=333.999.0.0)，非常有意思的辩手
# 2. Youtube
#    - [*跟李沐学AI*](https://www.youtube.com/@AI-qb8eh)，深度学习、数据分析等教学视频
#    - [*小lin说*](https://www.youtube.com/@xiao_lin_shuo)，金融史和社会热点挖掘
#    - [*MIYA*](https://www.youtube.com/@MIYA_Bassist)，电贝斯cover并且附有乐谱系列
# 3. 公众号
#    - *毕导*、*China Daily*、*人物*、*机器之心*、*三言两语杂货社*等

# %% [markdown]
# - 你对编程的喜欢/厌恶程度是多少？1为很厌恶，10为很喜欢。

# %% [markdown]
# 我想我会打***7.5***分。编程完成一些lab或者小项目是挺有成就感的事情，但是我好像也没有对它过分狂热，可以说是喜欢的，只不过它还没有完全变成一项想一想就会很兴奋的爱好。

# %% [markdown]
# - 你喜欢/**不**喜欢的上课方式是怎样的？

# %% [markdown]
# 1. **不**喜欢：
#      - 念ppt的课堂，尤其是陈年老旧从不更新的ppt，更更尤其是像编程这类更新迭代非常快速的学科下依然使用十几二十年前的材料的
#      - 非常奉行教材的课程，和上面提及的照本宣科类似，尽管教材的确是这一领域的经典
#      - 很少与学生互动，基本不关心台下人反应的课堂，只沉浸在自己的世界里
#      - 高傲地贬低学生无知、时常透露出优越感的上课方式，没有“术业有专攻，闻道有先后”之感
# 2. 喜欢：
#      - 与时俱进，教学材料与学科前沿接轨，教学方法也逐年改进的课堂
#      - 拥有对所教授学科的深入了解，并且能以批判性思维看待现有的所有教材和教学方式
#      - 和学生有适当的互动，但也不会强求学生的反应，而是让愿意互动的学生更大胆互动、让不愿意互动的学生以更好地方式互动
#      - 对上课要求、作业提交等事项陈述清晰，不朝令夕改

# %% [markdown]
# ## 2. 安装 Ray

# %% [markdown]
# 请参照课程文档《Ray 安装》的提示配置好运行 Ray 的环境，并用如下的代码验证 Conda 和 Ray 安装是否成功：

# %%
# !conda info
# Out:
# 'conda' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
import ray
ray.init()
# Out:
# 2024-02-29 22:46:43,210	INFO worker.py:1724 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.0', ray_version='2.9.3', ray_commit='62655e11ed76509b78654b60be67bc59f8f3460a', protocol_version=None)

# %% [markdown]
# 查看环境变量：

# %%
import os
print(os.getenv("RAY_ENABLE_WINDOWS_OR_OSX_CLUSTER"))
# Out:
# 1
